# %%
# Dependencies and config file
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key, api_key2, api_key3, api_key4, api_key5, api_key6, api_key7
import openweathermapy as owm
from citipy import citipy
from random import randint
import numpy as np

# %%
# Randomly select 500 unique latitudes
latitude_list = []

for x in range(2500):
    latitude_list.append(np.random.uniform(low=-180.0, high=180, size=None))

# Convert list to series
latitude_list_series = pd.Series(latitude_list)

# %%
# Randomly select 500 unique longitudes
longitude_list = []

for x in range(2500):
    longitude_list.append(np.random.uniform(low=-90, high = 90))
    #print(longitude)

# Convert list to series
longitude_list_series = pd.Series(longitude_list)

# %%
# Concatentate the series into a df
lat_and_long = pd.concat([latitude_list_series, longitude_list_series], axis=1)
#lat_and_long.head(10)
#lat_and_long = lat_and_long.set_index(0)
lat_and_long.head(10)
# Out:
#             0          1
# 0  163.149885  39.863434
# 1   25.838134   7.943389
# 2  -83.139126 -64.716607
# 3  137.849615 -44.755691
# 4   -9.802006  30.781193
# 5  103.099615 -38.255430
# 6  -55.153063 -16.330975
# 7  -78.805467  19.106423
# 8  126.310946 -57.847387
# 9   84.827680  20.658050

# %%
# Create new empty columns and add to existing dataframe 
#lat_and_long["City"] = ("")
#lat_and_long["Country Code"] = ("")
#lat_and_long["Temperature"] =("")
#lat_and_long["Cloudiness"] =("")
#lat_and_long["Windspeed"] =("")
#lat_and_long.head(10)
# Rename columns
lat_and_long = lat_and_long.rename(columns={0: "Latitude", 1:"Longitude"})
lat_and_long.head()
# Out:
#      Latitude  Longitude
# 0  163.149885  39.863434
# 1   25.838134   7.943389
# 2  -83.139126 -64.716607
# 3  137.849615 -44.755691
# 4   -9.802006  30.781193

# %%
# Blank column for holiding the city name
cities = []

#row_counter = 0
for index, row in lat_and_long.iterrows():
    x = row["Latitude"]
    y = row["Longitude"]
    city = citipy.nearest_city(x,y)
    #lat_and_long.set_value(index, "City", citipy.nearest_city(x, y).city_name)
    lat_and_long.set_value(index, "City", city.city_name)
    lat_and_long.set_value(index, "Country Code", city.country_code)
    city_list = city.city_name
    cities.append(city_list)
#lat_and_long
#print(len(city_list))
#print(cities)

cities = pd.Series(cities)

# %%
#lat_and_long.head()
# Out:
#      Latitude  Longitude          City Country Code
# 0  163.149885  39.863434  longyearbyen           sj
# 1   25.838134   7.943389           gat           ly
# 2  -83.139126 -64.716607       ushuaia           ar
# 3  137.849615 -44.755691        narsaq           gl
# 4   -9.802006  30.781193        kasama           zm

# %%
lat_and_long = lat_and_long.drop_duplicates(subset = ["City"], keep = "first")
lat_and_long = lat_and_long.reset_index(drop=True)
lat_and_long.head()
# Out:
#      Latitude  Longitude          City Country Code
# 0  163.149885  39.863434  longyearbyen           sj
# 1   25.838134   7.943389           gat           ly
# 2  -83.139126 -64.716607       ushuaia           ar
# 3  137.849615 -44.755691        narsaq           gl
# 4   -9.802006  30.781193        kasama           zm

# %%
# Create empty list for storing city + country code together
city_country_list = []

# Iterate through df to populate the list of cities with their country code
for index, row in lat_and_long.iterrows():
    x = row["City"]
    y = row["Country Code"]
    city = str(x) + "," + str(y)
    #print(city)
    if city not in city_country_list:
        city_country_list.append(city) 
#print(city_country_list)

# %%
# Create settings dictionary and summary list
settings = {"units": "metric", "appid": api_key5}
summary = ["name", "sys.country", "coord.lon", "coord.lat", "main.temp", "wind.speed", "clouds.all"]

# Create a list to hold the dictionaries
meta_weather_summary = []
# loop through the city,country list to get the current weather
for x in city_country_list:
    # Print a log of each city as it is being processed
    print(f"Retrieving data for city:{x}.")
    try:
        current_weather = owm.get_current(x, **settings)
        weather_summary = current_weather(*summary)
        meta_weather_summary.append(weather_summary)
        #print(f"the weather is:{weather_summary}.")
        
    except: 
        print("No data found.")
#print(meta_weather_summary)
# Out:
# Retrieving data for city:longyearbyen,sj.
# Retrieving data for city:gat,ly.
# No data found.
# Retrieving data for city:ushuaia,ar.
# Retrieving data for city:narsaq,gl.
# Retrieving data for city:kasama,zm.
# Retrieving data for city:upernavik,gl.
# Retrieving data for city:jamestown,sh.
# Retrieving data for city:bredasdorp,za.
# Retrieving data for city:qaanaaq,gl.
# Retrieving data for city:diamantino,br.
# Retrieving data for city:mahebourg,mu.
# Retrieving data for city:albany,au.
# Retrieving data for city:port alfred,za.
# Retrieving data for city:yar-sale,ru.
# Retrieving data for city:tsihombe,mg.
# No data found.
# Retrieving data for city:coquimbo,cl.
# Retrieving data for city:barentsburg,sj.
# No data found.
# Retrieving data for city:dikson,ru.
# Retrieving data for city:illoqqortoormiut,gl.
# No data found.
# Retrieving data for city:caravelas,br.
# Retrieving data for city:talnakh,ru.
# Retrieving data for city:srivardhan,in.
# Retrieving data for city:felidhoo,mv.
# No data found.
# Retrieving data for city:port elizabeth,za.
# Retrieving data for city:belushya guba,ru.
# No data found.
# Retrieving data for city:aksarka,ru.
# Retrieving data for city:inirida,co.
# Retrieving data for city:amapa,br.
# Retrieving data for city:grindavik,is.
# Retrieving data for city:taolanaro,mg.
# No data found.
# Retrieving data for city:bambous virieux,mu.
# Retrieving data for city:marcona,pe.
# No data found.
# Retrieving data for city:mehamn,no.
# Retrieving data for city:georgetown,sh.
# Retrieving data for city:souillac,mu.
# Retrieving data for city:hithadhoo,mv.
# Retrieving data for city:diffa,ne.
# Retrieving data for city:busselton,au.
# Retrieving data for city:arlit,ne.
# Retrieving data for city:chota,pe.
# Retrieving data for city:aksu,cn.
# Retrieving data for city:luena,ao.
# Retrieving data for city:lebu,cl.
# Retrieving data for city:ajdabiya,ly.
# Retrieving data for city:sao joao da barra,br.
# Retrieving data for city:praia da vitoria,pt.
# Retrieving data for city:ponta do sol,cv.
# Retrieving data for city:grand river south east,mu.
# No data found.
# Retrieving data for city:dhidhdhoo,mv.
# Retrieving data for city:olafsvik,is.
# No data found.
# Retrieving data for city:amderma,ru.
# No data found.
# Retrieving data for city:cayenne,gf.
# Retrieving data for city:mukono,ug.
# Retrieving data for city:jacareacanga,br.
# Retrieving data for city:codrington,ag.
# No data found.
# Retrieving data for city:pisco,pe.
# Retrieving data for city:kruisfontein,za.
# Retrieving data for city:inverness,ca.
# Retrieving data for city:ilulissat,gl.
# Retrieving data for city:west bay,ky.
# Retrieving data for city:nanortalik,gl.
# Retrieving data for city:husavik,is.
# Retrieving data for city:dese,et.
# Retrieving data for city:saint-philippe,re.
# Retrieving data for city:pozo colorado,py.
# Retrieving data for city:rio gallegos,ar.
# Retrieving data for city:hermanus,za.
# Retrieving data for city:simoes,br.
# Retrieving data for city:louisbourg,ca.
# No data found.
# Retrieving data for city:cidreira,br.
# Retrieving data for city:iqaluit,ca.
# Retrieving data for city:aliwal north,za.
# Retrieving data for city:ribeira grande,pt.
# Retrieving data for city:mar del plata,ar.
# Retrieving data for city:chuy,uy.
# Retrieving data for city:vila velha,br.
# Retrieving data for city:berbera,so.
# Retrieving data for city:camacha,pt.
# Retrieving data for city:mayumba,ga.
# Retrieving data for city:teguise,es.
# Retrieving data for city:itarema,br.
# Retrieving data for city:azrow,af.
# No data found.
# Retrieving data for city:laguna,br.
# No data found.
# Retrieving data for city:port orange,us.
# Retrieving data for city:mahibadhoo,mv.
# Retrieving data for city:siniscola,it.
# Retrieving data for city:qasigiannguit,gl.
# Retrieving data for city:yarim,ye.
# Retrieving data for city:saldanha,za.
# Retrieving data for city:wallaceburg,ca.
# Retrieving data for city:awassa,et.
# No data found.
# Retrieving data for city:nuuk,gl.
# Retrieving data for city:rawson,ar.
# Retrieving data for city:armacao de pera,pt.
# Retrieving data for city:henties bay,na.
# Retrieving data for city:punta arenas,cl.
# Retrieving data for city:faya,td.
# No data found.
# Retrieving data for city:cape town,za.
# Retrieving data for city:chapais,ca.
# Retrieving data for city:maamba,zm.
# Retrieving data for city:anar darreh,af.
# No data found.
# Retrieving data for city:sire,et.
# Retrieving data for city:marsh harbour,bs.
# Retrieving data for city:victoria,sc.
# Retrieving data for city:oranjemund,na.
# Retrieving data for city:clyde river,ca.
# Retrieving data for city:turayf,sa.
# Retrieving data for city:pangnirtung,ca.
# Retrieving data for city:high rock,bs.
# Retrieving data for city:viedma,ar.
# Retrieving data for city:makokou,ga.
# Retrieving data for city:dubai,ae.
# Retrieving data for city:valerianovsk,ru.
# Retrieving data for city:attawapiskat,ca.
# No data found.
# Retrieving data for city:barra do garcas,br.
# Retrieving data for city:saint-pierre,pm.
# Retrieving data for city:guadalupe,co.
# Retrieving data for city:nyzhni sirohozy,ua.
# Retrieving data for city:nantucket,us.
# Retrieving data for city:dakar,sn.
# Retrieving data for city:sorland,no.
# Retrieving data for city:sao filipe,cv.
# Retrieving data for city:corinth,us.
# Retrieving data for city:east london,za.
# Retrieving data for city:mandiana,gn.
# Retrieving data for city:port blair,in.
# Retrieving data for city:karkaralinsk,kz.
# No data found.
# Retrieving data for city:kuloy,ru.
# Retrieving data for city:luderitz,na.
# Retrieving data for city:honningsvag,no.
# Retrieving data for city:rio grande,br.
# Retrieving data for city:bengkulu,id.
# No data found.
# Retrieving data for city:totton,gb.
# Retrieving data for city:bolungarvik,is.
# No data found.
# Retrieving data for city:wilmington,us.
# Retrieving data for city:trinidad,bo.
# Retrieving data for city:kasra,tn.
# No data found.
# Retrieving data for city:sumbe,ao.
# Retrieving data for city:kitui,ke.
# Retrieving data for city:barawe,so.
# No data found.
# Retrieving data for city:hofn,is.
# Retrieving data for city:hobyo,so.
# Retrieving data for city:temnikov,ru.
# Retrieving data for city:encruzilhada do sul,br.
# Retrieving data for city:borazjan,ir.
# Retrieving data for city:miresu mare,ro.
# Retrieving data for city:harper,lr.
# Retrieving data for city:diamantina,br.
# Retrieving data for city:kroonstad,za.
# Retrieving data for city:coihaique,cl.
# Retrieving data for city:ambilobe,mg.
# Retrieving data for city:tabuk,sa.
# Retrieving data for city:saint george,bm.
# Retrieving data for city:inhambane,mz.
# Retrieving data for city:torbay,ca.
# Retrieving data for city:paita,pe.
# Retrieving data for city:cachira,co.
# Retrieving data for city:ancud,cl.
# Retrieving data for city:havelock,us.
# Retrieving data for city:palafrugell,es.
# Retrieving data for city:vardo,no.
# Retrieving data for city:kevsala,ru.
# Retrieving data for city:bonthe,sl.
# Retrieving data for city:bathsheba,bb.
# Retrieving data for city:bubaque,gw.
# Retrieving data for city:raudeberg,no.
# Retrieving data for city:dawlatabad,af.
# Retrieving data for city:cockburn town,bs.
# Retrieving data for city:zaysan,kz.
# Retrieving data for city:bolgatanga,gh.
# Retrieving data for city:tiznit,ma.
# Retrieving data for city:cockburn harbour,tc.
# No data found.
# Retrieving data for city:moose factory,ca.
# Retrieving data for city:mecca,sa.
# Retrieving data for city:dutse,ng.
# Retrieving data for city:tasiilaq,gl.
# Retrieving data for city:havre-saint-pierre,ca.
# Retrieving data for city:kinsale,ie.
# Retrieving data for city:hamilton,bm.
# Retrieving data for city:khomeynishahr,ir.
# No data found.
# Retrieving data for city:klaksvik,fo.
# Retrieving data for city:piacabucu,br.
# Retrieving data for city:roald,no.
# Retrieving data for city:upington,za.
# Retrieving data for city:jiddah,sa.
# No data found.
# Retrieving data for city:ostrovnoy,ru.
# Retrieving data for city:vangaindrano,mg.
# Retrieving data for city:matay,eg.
# Retrieving data for city:yaroslavl,ru.
# Retrieving data for city:gao,ml.
# Retrieving data for city:lagoa,pt.
# Retrieving data for city:abdanan,ir.
# Retrieving data for city:polunochnoye,ru.
# Retrieving data for city:porto torres,it.
# Retrieving data for city:arkhangelos,gr.
# No data found.
# Retrieving data for city:curillo,co.
# Retrieving data for city:tessalit,ml.
# Retrieving data for city:tortoli,it.
# Retrieving data for city:kudahuvadhoo,mv.
# Retrieving data for city:comodoro rivadavia,ar.
# Retrieving data for city:arraial do cabo,br.
# Retrieving data for city:bokspits,bw.
# No data found.
# Retrieving data for city:kimi,gr.
# No data found.
# Retrieving data for city:san martin,ar.
# Retrieving data for city:brae,gb.
# Retrieving data for city:golspie,gb.
# Retrieving data for city:namibe,ao.
# Retrieving data for city:osijek,hr.
# Retrieving data for city:itacare,br.
# Retrieving data for city:pimentel,pe.
# Retrieving data for city:san andres,co.
# Retrieving data for city:uwayl,sd.
# No data found.
# Retrieving data for city:bijapur,in.
# No data found.
# Retrieving data for city:buncrana,ie.
# Retrieving data for city:richards bay,za.
# Retrieving data for city:iranshahr,ir.
# Retrieving data for city:oriximina,br.
# Retrieving data for city:braganca,pt.
# Retrieving data for city:burgeo,ca.
# Retrieving data for city:valparaiso,cl.
# Retrieving data for city:llandrindod wells,gb.
# Retrieving data for city:tigzirt,dz.
# Retrieving data for city:bhainsdehi,in.
# Retrieving data for city:naryan-mar,ru.
# Retrieving data for city:kuusamo,fi.
# Retrieving data for city:mahaicony,gy.
# No data found.
# Retrieving data for city:nadym,ru.
# Retrieving data for city:khirkiya,in.
# Retrieving data for city:taltal,cl.
# Retrieving data for city:abay,kz.
# Retrieving data for city:bonfim,br.
# Retrieving data for city:saint anthony,ca.
# No data found.
# Retrieving data for city:nakapiripirit,ug.
# Retrieving data for city:soyo,ao.
# Retrieving data for city:adrar,dz.
# Retrieving data for city:filingue,ne.
# Retrieving data for city:san carlos del zulia,ve.
# Retrieving data for city:killybegs,ie.
# Retrieving data for city:tasbuget,kz.
# No data found.
# Retrieving data for city:achisay,kz.
# No data found.
# Retrieving data for city:goma,cd.
# Retrieving data for city:awbari,ly.
# Retrieving data for city:kalmunai,lk.
# Retrieving data for city:mullaitivu,lk.
# No data found.
# Retrieving data for city:middlebury,us.
# Retrieving data for city:kasempa,zm.
# Retrieving data for city:karmala,in.
# Retrieving data for city:los llanos de aridane,es.
# Retrieving data for city:krasnoarmeysk,kz.
# No data found.
# Retrieving data for city:thinadhoo,mv.
# Retrieving data for city:plock,pl.
# Retrieving data for city:idenao,cm.
# Retrieving data for city:hazorasp,uz.
# Retrieving data for city:kortkeros,ru.
# Retrieving data for city:dingle,ie.
# Retrieving data for city:abnub,eg.
# Retrieving data for city:chik,ru.
# Retrieving data for city:bulungu,cd.
# Retrieving data for city:syracuse,it.
# No data found.
# Retrieving data for city:martil,ma.
# Retrieving data for city:sfantu gheorghe,ro.
# Retrieving data for city:karaul,ru.
# No data found.
# Retrieving data for city:birjand,ir.
# Retrieving data for city:quatre cocos,mu.
# Retrieving data for city:dabhol,in.
# Retrieving data for city:thompson,ca.
# Retrieving data for city:nortelandia,br.
# Retrieving data for city:teofilo otoni,br.
# Retrieving data for city:coxim,br.
# Retrieving data for city:safwah,sa.
# No data found.
# Retrieving data for city:koppal,in.
# Retrieving data for city:riyadh,sa.
# Retrieving data for city:bilma,ne.
# Retrieving data for city:filadelfia,py.
# Retrieving data for city:barcelos,br.
# Retrieving data for city:malwan,in.
# No data found.
# Retrieving data for city:koungou,yt.
# Retrieving data for city:tandlianwala,pk.
# Retrieving data for city:monkey bay,mw.
# Retrieving data for city:lokosovo,ru.
# Retrieving data for city:nador,ma.
# Retrieving data for city:touros,br.
# Retrieving data for city:baijiantan,cn.
# Retrieving data for city:plettenberg bay,za.
# Retrieving data for city:aden,ye.
# Retrieving data for city:trairi,br.
# Retrieving data for city:saint-francois,gp.
# Retrieving data for city:sisimiut,gl.
# Retrieving data for city:skibbereen,ie.
# Retrieving data for city:odesskoye,ru.
# Retrieving data for city:mogadishu,so.
# Retrieving data for city:mocuba,mz.
# Retrieving data for city:luau,ao.
# Retrieving data for city:curanilahue,cl.
# Retrieving data for city:young,uy.
# Retrieving data for city:sarahan,in.
# Retrieving data for city:sabile,lv.
# Retrieving data for city:sorata,bo.
# Retrieving data for city:dudinka,ru.
# Retrieving data for city:begles,fr.
# Retrieving data for city:kapoeta,sd.
# No data found.
# Retrieving data for city:tumannyy,ru.
# No data found.
# Retrieving data for city:scalea,it.
# Retrieving data for city:margate,za.
# Retrieving data for city:sperkhoyia,gr.
# Retrieving data for city:diplo,pk.
# Retrieving data for city:leh,in.
# Retrieving data for city:senador jose porfirio,br.
# Retrieving data for city:madisonville,us.
# Retrieving data for city:scottsburgh,za.
# No data found.
# Retrieving data for city:lagunas,pe.
# Retrieving data for city:paraipaba,br.
# Retrieving data for city:kuche,cn.
# No data found.
# Retrieving data for city:maraa,br.
# Retrieving data for city:eyl,so.
# Retrieving data for city:salinopolis,br.
# Retrieving data for city:calvinia,za.
# Retrieving data for city:sur,om.
# Retrieving data for city:armacao dos buzios,br.
# No data found.
# Retrieving data for city:vestmannaeyjar,is.
# Retrieving data for city:conceicao da barra,br.
# Retrieving data for city:toliary,mg.
# No data found.
# Retrieving data for city:kattivakkam,in.
# Retrieving data for city:antsohihy,mg.
# Retrieving data for city:dire dawa,et.
# Retrieving data for city:gambela,et.
# Retrieving data for city:tazovskiy,ru.
# Retrieving data for city:donskoye,ru.
# Retrieving data for city:necochea,ar.
# Retrieving data for city:ketchenery,ru.
# No data found.
# Retrieving data for city:harqalah,tn.
# Retrieving data for city:stornoway,gb.
# Retrieving data for city:maldonado,uy.
# Retrieving data for city:platanos,gr.
# Retrieving data for city:usinsk,ru.
# Retrieving data for city:williamsburg,us.
# Retrieving data for city:saint-joseph,re.
# Retrieving data for city:jalu,ly.
# Retrieving data for city:snezhnogorsk,ru.
# Retrieving data for city:assai,br.
# Retrieving data for city:menongue,ao.
# Retrieving data for city:kulhudhuffushi,mv.
# Retrieving data for city:mocambique,mz.
# No data found.
# Retrieving data for city:tukrah,ly.
# No data found.
# Retrieving data for city:castro,cl.
# Retrieving data for city:itapecerica,br.
# Retrieving data for city:pskov,ru.
# Retrieving data for city:rovaniemi,fi.
# Retrieving data for city:koutiala,ml.
# Retrieving data for city:kashi,cn.
# Retrieving data for city:kedrovyy,ru.
# Retrieving data for city:durban,za.
# Retrieving data for city:tromso,no.
# Retrieving data for city:nankana sahib,pk.
# Retrieving data for city:san antero,co.
# Retrieving data for city:warqla,dz.
# No data found.
# Retrieving data for city:olinda,br.
# Retrieving data for city:khorixas,na.
# Retrieving data for city:umzimvubu,za.
# No data found.
# Retrieving data for city:hernani,es.
# Retrieving data for city:whittlesea,za.
# Retrieving data for city:artyom,az.
# Retrieving data for city:vestmanna,fo.
# Retrieving data for city:gafanha da encarnacao,pt.
# Retrieving data for city:oistins,bb.
# Retrieving data for city:virginia beach,us.
# Retrieving data for city:lidzbark warminski,pl.
# Retrieving data for city:macas,ec.
# Retrieving data for city:amot,no.
# Retrieving data for city:taraz,kz.
# Retrieving data for city:vagay,ru.
# Retrieving data for city:pitimbu,br.
# Retrieving data for city:karachi,pk.
# Retrieving data for city:port-gentil,ga.
# Retrieving data for city:akdagmadeni,tr.
# Retrieving data for city:nsanje,mw.
# Retrieving data for city:tikhoretsk,ru.
# Retrieving data for city:rensvik,no.
# Retrieving data for city:pedernales,do.
# Retrieving data for city:punto fijo,ve.
# Retrieving data for city:buraydah,sa.
# Retrieving data for city:hualmay,pe.
# Retrieving data for city:ginda,er.
# No data found.
# Retrieving data for city:pop,uz.
# Retrieving data for city:klodzko,pl.
# Retrieving data for city:muskegon,us.
# Retrieving data for city:muzhi,ru.
# Retrieving data for city:bur gabo,so.
# No data found.
# Retrieving data for city:bay roberts,ca.
# Retrieving data for city:garowe,so.
# Retrieving data for city:kizilskoye,ru.
# Retrieving data for city:krasnotorka,ua.
# Retrieving data for city:hukuntsi,bw.
# Retrieving data for city:de aar,za.
# Retrieving data for city:sao joao do piaui,br.
# Retrieving data for city:rocha,uy.
# Retrieving data for city:great yarmouth,gb.
# Retrieving data for city:senaki,ge.
# Retrieving data for city:tenenkou,ml.
# Retrieving data for city:empangeni,za.
# Retrieving data for city:morondava,mg.
# Retrieving data for city:meulaboh,id.
# Retrieving data for city:navlya,ru.
# Retrieving data for city:bisira,pa.
# Retrieving data for city:jijiga,et.
# Retrieving data for city:betsiamites,ca.
# Retrieving data for city:ayorou,ne.
# Retrieving data for city:la paz centro,ni.
# Retrieving data for city:pietersburg,za.
# No data found.
# Retrieving data for city:kollumerland,nl.
# No data found.
# Retrieving data for city:rorvik,no.
# Retrieving data for city:havoysund,no.
# Retrieving data for city:zelenoborsk,ru.
# Retrieving data for city:tokat,tr.
# Retrieving data for city:capitan bado,py.
# Retrieving data for city:sabha,jo.
# Retrieving data for city:santa maria,cv.
# Retrieving data for city:primorsko-akhtarsk,ru.
# Retrieving data for city:leghorn,it.
# No data found.
# Retrieving data for city:port hawkesbury,ca.
# Retrieving data for city:mankovo-kalitvenskoye,ru.
# No data found.
# Retrieving data for city:borovoy,ru.
# Retrieving data for city:qafsah,tn.
# No data found.
# Retrieving data for city:maloshuyka,ru.
# No data found.
# Retrieving data for city:san jose,bo.
# Retrieving data for city:greaca,ro.
# Retrieving data for city:tubuala,pa.
# Retrieving data for city:saint-prosper,ca.
# Retrieving data for city:mokrousovo,ru.
# Retrieving data for city:vicuna,cl.
# Retrieving data for city:svetlyy,ru.
# No data found.
# Retrieving data for city:raisinghnagar,in.
# Retrieving data for city:lephepe,bw.
# No data found.
# Retrieving data for city:porto novo,cv.
# Retrieving data for city:luanda,ao.
# Retrieving data for city:kavaratti,in.
# Retrieving data for city:berlevag,no.
# Retrieving data for city:mbandaka,cd.
# Retrieving data for city:praia,cv.
# Retrieving data for city:pribelskiy,ru.
# No data found.
# Retrieving data for city:cubara,co.
# Retrieving data for city:atbasar,kz.
# Retrieving data for city:santa rosa,ar.
# Retrieving data for city:saint-leu,re.
# Retrieving data for city:krutinka,ru.
# Retrieving data for city:the valley,ai.
# Retrieving data for city:vila do maio,cv.
# Retrieving data for city:pimenta bueno,br.
# Retrieving data for city:skiros,gr.
# No data found.
# Retrieving data for city:visby,se.
# Retrieving data for city:porto nacional,br.
# Retrieving data for city:marsa matruh,eg.
# Retrieving data for city:colorado,br.
# Retrieving data for city:wakiso,ug.
# Retrieving data for city:khor,qa.
# No data found.
# Retrieving data for city:atocha,bo.
# Retrieving data for city:omboue,ga.
# Retrieving data for city:taoudenni,ml.
# Retrieving data for city:atkarsk,ru.
# Retrieving data for city:tandil,ar.
# Retrieving data for city:san luis,ar.
# Retrieving data for city:salalah,om.
# Retrieving data for city:colonia,uy.
# No data found.
# Retrieving data for city:nedjo,et.
# Retrieving data for city:bardiyah,ly.
# Retrieving data for city:kangaatsiaq,gl.
# Retrieving data for city:kousseri,cm.
# Retrieving data for city:abu dhabi,ae.
# Retrieving data for city:ilhabela,br.
# Retrieving data for city:sistranda,no.
# Retrieving data for city:ibra,om.
# Retrieving data for city:kusk,af.
# No data found.
# Retrieving data for city:qaqortoq,gl.
# Retrieving data for city:jupiter,us.
# Retrieving data for city:sambava,mg.
# Retrieving data for city:carrickfergus,gb.
# Retrieving data for city:conde,br.
# Retrieving data for city:kidal,ml.
# Retrieving data for city:palmas,br.
# Retrieving data for city:stepnyak,kz.
# Retrieving data for city:asheboro,us.
# Retrieving data for city:sabzevar,ir.
# Retrieving data for city:rosetta,eg.
# Retrieving data for city:vinnytsya,ua.
# Retrieving data for city:bom jesus,br.
# Retrieving data for city:toftir,fo.
# No data found.
# Retrieving data for city:gamba,ga.
# Retrieving data for city:vila franca do campo,pt.
# Retrieving data for city:reyes,bo.
# Retrieving data for city:salinas,ec.
# Retrieving data for city:hvide sande,dk.
# Retrieving data for city:ambanja,mg.
# Retrieving data for city:novo aripuana,br.
# Retrieving data for city:conyers,us.
# Retrieving data for city:sindor,ru.
# Retrieving data for city:bela,pk.
# Retrieving data for city:umm lajj,sa.
# Retrieving data for city:bata,gq.
# Retrieving data for city:sangmelima,cm.
# Retrieving data for city:bandarbeyla,so.
# Retrieving data for city:listvyanskiy,ru.
# Retrieving data for city:locri,it.
# Retrieving data for city:pervomayskoye,ru.
# Retrieving data for city:ibiapina,br.
# Retrieving data for city:pinheiro machado,br.
# Retrieving data for city:sakakah,sa.
# No data found.
# Retrieving data for city:gweta,bw.
# Retrieving data for city:grand gaube,mu.
# Retrieving data for city:kuppam,in.
# Retrieving data for city:oranjestad,aw.
# Retrieving data for city:severodvinsk,ru.
# Retrieving data for city:bulaevo,kz.
# Retrieving data for city:shira,ru.
# Retrieving data for city:sargatskoye,ru.

# %%
# Convert list of tuples to df
new_meta = pd.DataFrame(list(meta_weather_summary))
new_meta.head()

# Change column labels
new_meta = new_meta.rename(columns={0:"City", 1:"Country Code", 2:"Longitude", 3:"Latitude", 4:"Temperature", 5:"Wind Speed", 6:"Cloudiness"})
new_meta.head(25)
# Out:
#                City Country Code  Longitude  Latitude  Temperature  \
# 0      Longyearbyen           SJ      15.64     78.22       -12.00
# 1           Ushuaia           AR     -68.31    -54.81         7.00
# 2            Narsaq           GL     -46.05     60.91        -4.00
# 3            Kasama           ZM      31.19    -10.21        26.11
# 4         Upernavik           GL     -56.15     72.79       -21.99
# 5         Jamestown           SH      -5.72    -15.94        23.24
# 6        Bredasdorp           ZA      20.04    -34.53        25.00
# 7           Qaanaaq           GL     -69.36     77.48       -24.29
# 8        Diamantino           BR     -56.44    -14.40        22.51
# 9         Mahebourg           MU      57.70    -20.41        27.00
# 10           Albany           AU     117.88    -35.02        13.59
# 11      Port Alfred           ZA      26.89    -33.59        26.34
# 12         Yar-Sale           RU      70.83     66.83       -24.24
# 13         Coquimbo           CL     -71.34    -29.95        13.00
# 14           Dikson           RU      80.55     73.51       -23.59
# 15        Caravelas           BR     -39.27    -17.73        27.39
# 16          Talnakh           RU      88.39     69.49        -7.59
# 17       Srivardhan           IN      73.02     18.03        25.91
# 18   Port Elizabeth           ZA      25.57    -33.92        24.00
# 19          Aksarka           RU      67.80     66.56       -24.62
# 20          Inirida           CO     -67.92      3.87        25.84
# 21            Amapa           BR     -56.23     -1.83        29.49
# 22        Grindavik           IS     -22.43     63.84         4.00
# 23  Bambous Virieux           MU      57.76    -20.34        27.00
# 24           Mehamn           NO      27.85     71.03        -3.30
#
#     Wind Speed  Cloudiness
# 0         3.10          75
# 1         6.20          75
# 2         2.60          20
# 3         3.46          32
# 4         4.56           0
# 5         0.86          12
# 6         4.60          24
# 7         3.31           0
# 8         1.66          92
# 9         0.50          40
# 10        4.11           0
# 11        5.11           0
# 12        6.61          20
# 13        2.10          90
# 14        6.56          20
# 15        5.36          56
# 16        6.26          80
# 17        1.76          12
# 18        3.60           0
# 19        1.21          24
# 20        1.36          76
# 21        1.86          20
# 22       13.40          90
# 23        0.50          40
# 24        6.20          75

# %%
# Save a CSV of all data retrieved

# %%
# Your objective is to build a series of scatter plots to showcase the following relationships:


# Humidity (%) vs. Latitude
# Cloudiness (%) vs. Latitude
# Wind Speed (mph) vs. Latitude

# %%
# Build a scatter plot that shows Temperature (F) vs. Latitude

plt.scatter(new_meta["Latitude"],
            new_meta["Temperature"],
            linewidths=1, marker="o",
            alpha=0.4, label="?")

# Label the graph and set axis limits
plt.title("Temperature vs. Latitude")
plt.ylabel("Temperature(C)")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim([, ])
#plt.ylim([, ])

# Save the figure as png image (for each scatter plot) 
plt.savefig("temp_vs_latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot that shows Temperature (F) vs. Latitude

plt.scatter(new_meta["Latitude"],
            new_meta["Cloudiness"],
            linewidths=1, marker="o",
            alpha=0.4, label="?")

# Label the graph and set axis limits
plt.title("Cloudiness vs. Latitude")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim([, ])
#plt.ylim([, ])

# Save the figure as png image (for each scatter plot) 
plt.savefig("cloudiness_vs_latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot that shows Wind Speed (F) vs. Latitude

plt.scatter(new_meta["Latitude"],
            new_meta["Wind Speed"],
            linewidths=1, marker="o",
            alpha=0.4, label="?")

# Label the graph and set axis limits
plt.title("Wind Speed vs. Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim([, ])
#plt.ylim([, ])

# Save the figure as png image (for each scatter plot) 
plt.savefig("windspeed_vs_latitude.png")

# Show plot
plt.show()
