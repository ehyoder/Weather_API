# %%
# Dependencies and config file
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key, api_key2, api_key3, api_key4, api_key5, api_key6, api_key7
import openweathermapy as owm
from citipy import citipy
from random import randint
import numpy as np

# %%
# Randomly select 500 unique latitudes (range adjusted after dropping duplicates)
latitude_list = []

for x in range(2800):
    latitude_list.append(np.random.uniform(low=-180.0, high=180, size=None))

# Convert list to series
latitude_list_series = pd.Series(latitude_list)

# %%
# Randomly select 500 unique longitudes (range adjusted after dropping duplicates)
longitude_list = []

for x in range(2800):
    longitude_list.append(np.random.uniform(low=-90, high = 90))
    #print(longitude)

# Convert list to series
longitude_list_series = pd.Series(longitude_list)

# %%
# Concatentate the series into a df
lat_and_long = pd.concat([latitude_list_series, longitude_list_series], axis=1)
lat_and_long.head()
# Out:
#             0          1
# 0 -159.514548 -36.591713
# 1   33.160221 -67.999292
# 2  -52.901356  69.619303
# 3  -48.582434  -5.171995
# 4   13.579288 -82.312284

# %%
# Rename columns
lat_and_long = lat_and_long.rename(columns={0: "Latitude", 1:"Longitude"})
lat_and_long.head()
# Out:
#      Latitude  Longitude
# 0 -159.514548 -36.591713
# 1   33.160221 -67.999292
# 2  -52.901356  69.619303
# 3  -48.582434  -5.171995
# 4   13.579288 -82.312284

# %%
# Create Blank list for holiding the city name
cities = []

# Iterate through latitudes and longitudes and use info from citipy to create a list of cities
for index, row in lat_and_long.iterrows():
    x = row["Latitude"]
    y = row["Longitude"]
    city = citipy.nearest_city(x,y)
    lat_and_long.set_value(index, "City", city.city_name)
    lat_and_long.set_value(index, "Country Code", city.country_code)
    city_list = city.city_name
    cities.append(city_list)

# Convert list to series
cities = pd.Series(cities)

# %%
# Drop duplicate cities from city column
lat_and_long = lat_and_long.drop_duplicates(subset = ["City"], keep = "first")
lat_and_long = lat_and_long.reset_index(drop=True)
lat_and_long.head()
# Out:
#      Latitude  Longitude            City Country Code
# 0 -159.514548 -36.591713         ushuaia           ar
# 1   33.160221 -67.999292        hamilton           bm
# 2  -52.901356  69.619303  saint-philippe           re
# 3  -48.582434  -5.171995       cape town           za
# 4   13.579288 -82.312284  puerto cabezas           ni

# %%
# Create empty list for storing city + country code together
city_country_list = []

# Iterate through df to populate the list of cities with their country code (to facilitate weather lookup) 
for index, row in lat_and_long.iterrows():
    x = row["City"]
    y = row["Country Code"]
    city = str(x) + "," + str(y)
    if city not in city_country_list:
        city_country_list.append(city)

# %%
# Create settings dictionary and summary list
settings = {"units": "imperial", "appid": api_key6}
summary = ["name", "sys.country", "coord.lon", "coord.lat", "main.temp", "wind.speed", "clouds.all", "main.humidity"]

# Create a list to hold the dictionaries
meta_weather_summary = []

# Iterate through the city + country code list to get the current weather for each
for x in city_country_list:
    # Print a log of each city as it is being processed, use except statement for incomplete data
    print(f"Retrieving data for city:{x}.")
    try:
        current_weather = owm.get_current(x, **settings)
        weather_summary = current_weather(*summary)
        meta_weather_summary.append(weather_summary) 
    except: 
        print("No data found.")
#print(meta_weather_summary)
# Out:
# Retrieving data for city:ushuaia,ar.
# Retrieving data for city:hamilton,bm.
# Retrieving data for city:saint-philippe,re.
# Retrieving data for city:cape town,za.
# Retrieving data for city:puerto cabezas,ni.
# Retrieving data for city:gilleleje,dk.
# Retrieving data for city:arraial do cabo,br.
# Retrieving data for city:malanje,ao.
# Retrieving data for city:vestmannaeyjar,is.
# Retrieving data for city:longyearbyen,sj.
# Retrieving data for city:qaanaaq,gl.
# Retrieving data for city:bredasdorp,za.
# Retrieving data for city:kochi,in.
# Retrieving data for city:hermanus,za.
# Retrieving data for city:san luis,ar.
# Retrieving data for city:saint anthony,ca.
# No data found.
# Retrieving data for city:baijiantan,cn.
# Retrieving data for city:salalah,om.
# Retrieving data for city:ushtobe,kz.
# Retrieving data for city:bambous virieux,mu.
# Retrieving data for city:suez,eg.
# Retrieving data for city:buraydah,sa.
# Retrieving data for city:illoqqortoormiut,gl.
# No data found.
# Retrieving data for city:iqaluit,ca.
# Retrieving data for city:port elizabeth,za.
# Retrieving data for city:ravar,ir.
# Retrieving data for city:upernavik,gl.
# Retrieving data for city:port alfred,za.
# Retrieving data for city:barentsburg,sj.
# No data found.
# Retrieving data for city:lima,pe.
# Retrieving data for city:sur,om.
# Retrieving data for city:belushya guba,ru.
# No data found.
# Retrieving data for city:ilulissat,gl.
# Retrieving data for city:benjamin constant,br.
# Retrieving data for city:jamestown,sh.
# Retrieving data for city:dikson,ru.
# Retrieving data for city:nova venecia,br.
# Retrieving data for city:pahalgam,in.
# Retrieving data for city:san cristobal,ec.
# Retrieving data for city:maniitsoq,gl.
# Retrieving data for city:shahreza,ir.
# Retrieving data for city:kalemie,cd.
# Retrieving data for city:sao felix do xingu,br.
# Retrieving data for city:amderma,ru.
# No data found.
# Retrieving data for city:victoria,sc.
# Retrieving data for city:balkanabat,tm.
# Retrieving data for city:humberto de campos,br.
# Retrieving data for city:ordu,tr.
# Retrieving data for city:miandrivazo,mg.
# Retrieving data for city:lagoa,pt.
# Retrieving data for city:goderich,sl.
# No data found.
# Retrieving data for city:taolanaro,mg.
# No data found.
# Retrieving data for city:souillac,mu.
# Retrieving data for city:punta arenas,cl.
# Retrieving data for city:tasiilaq,gl.
# Retrieving data for city:mehamn,no.
# Retrieving data for city:narsaq,gl.
# Retrieving data for city:damaturu,ng.
# Retrieving data for city:gayny,ru.
# Retrieving data for city:neyshabur,ir.
# Retrieving data for city:cap malheureux,mu.
# Retrieving data for city:busselton,au.
# Retrieving data for city:carnarvon,au.
# Retrieving data for city:albany,au.
# Retrieving data for city:torbay,ca.
# Retrieving data for city:acarau,br.
# No data found.
# Retrieving data for city:geraldton,au.
# Retrieving data for city:beyneu,kz.
# Retrieving data for city:bolu,tr.
# Retrieving data for city:gurupa,br.
# No data found.
# Retrieving data for city:kalmeshwar,in.
# Retrieving data for city:chuy,uy.
# Retrieving data for city:vicosa,br.
# Retrieving data for city:namibe,ao.
# Retrieving data for city:grand river south east,mu.
# No data found.
# Retrieving data for city:jackson,us.
# Retrieving data for city:olinda,br.
# Retrieving data for city:banepa,np.
# Retrieving data for city:vangaindrano,mg.
# Retrieving data for city:makat,kz.
# Retrieving data for city:hambantota,lk.
# Retrieving data for city:ambovombe,mg.
# Retrieving data for city:hithadhoo,mv.
# Retrieving data for city:isla mujeres,mx.
# Retrieving data for city:matara,lk.
# Retrieving data for city:port hawkesbury,ca.
# Retrieving data for city:amapa,br.
# Retrieving data for city:virginia beach,us.
# Retrieving data for city:bani walid,ly.
# Retrieving data for city:port blair,in.
# Retrieving data for city:trincomalee,lk.
# Retrieving data for city:leh,in.
# Retrieving data for city:nalut,ly.
# Retrieving data for city:ouango,cf.
# No data found.
# Retrieving data for city:saldanha,za.
# Retrieving data for city:tourlaville,fr.
# Retrieving data for city:banda aceh,id.
# Retrieving data for city:nanortalik,gl.
# Retrieving data for city:pasni,pk.
# Retrieving data for city:saurimo,ao.
# Retrieving data for city:bourges,fr.
# Retrieving data for city:puquio,pe.
# Retrieving data for city:east london,za.
# Retrieving data for city:tsybli,ua.
# Retrieving data for city:kruisfontein,za.
# Retrieving data for city:gamba,ga.
# Retrieving data for city:roald,no.
# Retrieving data for city:bajil,ye.
# Retrieving data for city:rennes,fr.
# Retrieving data for city:dvinskoy,ru.
# Retrieving data for city:thompson,ca.
# Retrieving data for city:hemsedal,no.
# Retrieving data for city:libreville,ga.
# Retrieving data for city:adamovka,ru.
# Retrieving data for city:attawapiskat,ca.
# No data found.
# Retrieving data for city:kedrovyy,ru.
# Retrieving data for city:sao filipe,cv.
# Retrieving data for city:tamandare,br.
# Retrieving data for city:skagastrond,is.
# No data found.
# Retrieving data for city:annau,tm.
# Retrieving data for city:karaul,ru.
# No data found.
# Retrieving data for city:nola,cf.
# Retrieving data for city:mar del plata,ar.
# Retrieving data for city:srivardhan,in.
# Retrieving data for city:springbok,za.
# Retrieving data for city:velikiy ustyug,ru.
# Retrieving data for city:solginskiy,ru.
# Retrieving data for city:emba,kz.
# No data found.
# Retrieving data for city:bonthe,sl.
# Retrieving data for city:coihaique,cl.
# Retrieving data for city:port-gentil,ga.
# Retrieving data for city:sawakin,sd.
# Retrieving data for city:saint george,bm.
# Retrieving data for city:muscle shoals,us.
# Retrieving data for city:clyde river,ca.
# Retrieving data for city:nouakchott,mr.
# Retrieving data for city:cidreira,br.
# Retrieving data for city:bosaso,so.
# Retrieving data for city:tumannyy,ru.
# No data found.
# Retrieving data for city:laguna,br.
# No data found.
# Retrieving data for city:vila franca do campo,pt.
# Retrieving data for city:ismailia,eg.
# Retrieving data for city:andselv,no.
# No data found.
# Retrieving data for city:ponta do sol,cv.
# Retrieving data for city:grindavik,is.
# Retrieving data for city:tsihombe,mg.
# No data found.
# Retrieving data for city:nata,bw.
# Retrieving data for city:hvolsvollur,is.
# No data found.
# Retrieving data for city:tromso,no.
# Retrieving data for city:praia,cv.
# Retrieving data for city:lerwick,gb.
# Retrieving data for city:ikovka,ru.
# Retrieving data for city:sciacca,it.
# Retrieving data for city:saint-francois,gp.
# Retrieving data for city:praia da vitoria,pt.
# Retrieving data for city:bansko,bg.
# Retrieving data for city:san rafael,ar.
# Retrieving data for city:luanda,ao.
# Retrieving data for city:cockburn town,tc.
# Retrieving data for city:paracatu,br.
# Retrieving data for city:maloy,no.
# Retrieving data for city:mocuba,mz.
# Retrieving data for city:pavilosta,lv.
# Retrieving data for city:marcona,pe.
# No data found.
# Retrieving data for city:aksu,cn.
# Retrieving data for city:georgetown,sh.
# Retrieving data for city:manakara,mg.
# Retrieving data for city:touros,br.
# Retrieving data for city:dingle,ie.
# Retrieving data for city:katsiveli,ua.
# No data found.
# Retrieving data for city:bathsheba,bb.
# Retrieving data for city:kaoma,zm.
# Retrieving data for city:ambilobe,mg.
# Retrieving data for city:den helder,nl.
# Retrieving data for city:aswan,eg.
# Retrieving data for city:paamiut,gl.
# Retrieving data for city:marawi,sd.
# Retrieving data for city:lavumisa,sz.
# Retrieving data for city:ippy,cf.
# Retrieving data for city:mahibadhoo,mv.
# Retrieving data for city:jalalabad,af.
# Retrieving data for city:kuche,cn.
# No data found.
# Retrieving data for city:bathurst,ca.
# Retrieving data for city:qabis,tn.
# No data found.
# Retrieving data for city:vredendal,za.
# Retrieving data for city:san juan de colon,ve.
# Retrieving data for city:cay,tr.
# Retrieving data for city:vardo,no.
# Retrieving data for city:codrington,ag.
# No data found.
# Retrieving data for city:ribeira grande,pt.
# Retrieving data for city:macapa,br.
# Retrieving data for city:chudniv,ua.
# Retrieving data for city:mitsamiouli,km.
# Retrieving data for city:azimur,ma.
# No data found.
# Retrieving data for city:havoysund,no.
# Retrieving data for city:bardiyah,ly.
# Retrieving data for city:catamarca,ar.
# No data found.
# Retrieving data for city:bloomington,us.
# Retrieving data for city:klaksvik,fo.
# Retrieving data for city:turukhansk,ru.
# Retrieving data for city:florianopolis,br.
# Retrieving data for city:pula,hr.
# Retrieving data for city:sinkat,sd.
# No data found.
# Retrieving data for city:nouadhibou,mr.
# Retrieving data for city:sorvag,fo.
# No data found.
# Retrieving data for city:vaxjo,se.
# No data found.
# Retrieving data for city:komatipoort,za.
# Retrieving data for city:great yarmouth,gb.
# Retrieving data for city:bumba,cd.
# Retrieving data for city:urubicha,bo.
# Retrieving data for city:angoche,mz.
# Retrieving data for city:gairo,tz.
# Retrieving data for city:jayanca,pe.
# Retrieving data for city:peniche,pt.
# Retrieving data for city:marataizes,br.
# Retrieving data for city:chyhyryn,ua.
# Retrieving data for city:sorland,no.
# Retrieving data for city:puerto asis,co.
# Retrieving data for city:adrar,dz.
# Retrieving data for city:sao joao da barra,br.
# Retrieving data for city:varzea da palma,br.
# Retrieving data for city:waynesboro,us.
# Retrieving data for city:belyy yar,ru.
# Retrieving data for city:dwarka,in.
# Retrieving data for city:san lorenzo,ar.
# Retrieving data for city:ancud,cl.
# Retrieving data for city:opuwo,na.
# Retrieving data for city:vuktyl,ru.
# Retrieving data for city:wyszkow,pl.
# Retrieving data for city:comodoro rivadavia,ar.
# Retrieving data for city:zaliznychne,ua.
# Retrieving data for city:kirkenes,no.
# Retrieving data for city:starosubkhangulovo,ru.
# Retrieving data for city:holguin,cu.
# Retrieving data for city:gouyave,gd.
# Retrieving data for city:mpigi,ug.
# Retrieving data for city:porto velho,br.
# Retrieving data for city:krasnoyarka,ru.
# Retrieving data for city:dabola,gn.
# Retrieving data for city:mahebourg,mu.
# Retrieving data for city:plettenberg bay,za.
# Retrieving data for city:dasoguz,tm.
# Retrieving data for city:mangrol,in.
# Retrieving data for city:trani,it.
# Retrieving data for city:faya,td.
# No data found.
# Retrieving data for city:manoel urbano,br.
# Retrieving data for city:albania,co.
# Retrieving data for city:songea,tz.
# Retrieving data for city:biltine,td.
# Retrieving data for city:villamontes,bo.
# Retrieving data for city:pangnirtung,ca.
# Retrieving data for city:saint-augustin,ca.
# Retrieving data for city:san andres,co.
# Retrieving data for city:bodden town,ky.
# Retrieving data for city:youghal,ie.
# Retrieving data for city:ler,sd.
# No data found.
# Retrieving data for city:castro,cl.
# Retrieving data for city:balykshi,kz.
# No data found.
# Retrieving data for city:abha,sa.
# Retrieving data for city:sibenik,hr.
# Retrieving data for city:bubaque,gw.
# Retrieving data for city:barrancas,co.
# Retrieving data for city:verkhovazhye,ru.
# Retrieving data for city:kangaba,ml.
# Retrieving data for city:louisbourg,ca.
# No data found.
# Retrieving data for city:aleksandrow kujawski,pl.
# Retrieving data for city:puerto carreno,co.
# Retrieving data for city:asosa,et.
# Retrieving data for city:grande-riviere,ca.
# No data found.
# Retrieving data for city:barreirinhas,br.
# Retrieving data for city:omboue,ga.
# Retrieving data for city:rawson,ar.
# Retrieving data for city:conde,br.
# Retrieving data for city:urumqi,cn.
# No data found.
# Retrieving data for city:abalak,ne.
# Retrieving data for city:zharkent,kz.
# Retrieving data for city:atasu,kz.
# Retrieving data for city:mursalimkino,ru.
# Retrieving data for city:marapanim,br.
# Retrieving data for city:marsa matruh,eg.
# Retrieving data for city:arak,ir.
# Retrieving data for city:taoudenni,ml.
# Retrieving data for city:coari,br.
# Retrieving data for city:sisimiut,gl.
# Retrieving data for city:minab,ir.
# Retrieving data for city:chapais,ca.
# Retrieving data for city:macon,fr.
# Retrieving data for city:verkhnyaya inta,ru.
# Retrieving data for city:luderitz,na.
# Retrieving data for city:walvis bay,na.
# Retrieving data for city:araouane,ml.
# Retrieving data for city:huntingdon,ca.
# Retrieving data for city:doha,kw.
# No data found.
# Retrieving data for city:madimba,tz.
# Retrieving data for city:aleksandrov gay,ru.
# Retrieving data for city:ballater,gb.
# Retrieving data for city:ewo,cg.
# Retrieving data for city:soria,es.
# Retrieving data for city:pitimbu,br.
# Retrieving data for city:axams,at.
# Retrieving data for city:harper,lr.
# Retrieving data for city:mount darwin,zw.
# Retrieving data for city:kasongo-lunda,cd.
# Retrieving data for city:saint combs,gb.
# No data found.
# Retrieving data for city:uusikaupunki,fi.
# Retrieving data for city:hofn,is.
# Retrieving data for city:aksarka,ru.
# Retrieving data for city:valle del guamuez,co.
# Retrieving data for city:pegnitz,de.
# Retrieving data for city:gari,ru.
# Retrieving data for city:dzhusaly,kz.
# No data found.
# Retrieving data for city:sarevere,ee.
# Retrieving data for city:warqla,dz.
# No data found.
# Retrieving data for city:bugulma,ru.
# Retrieving data for city:tome-acu,br.
# No data found.
# Retrieving data for city:pokhara,np.
# Retrieving data for city:sioux lookout,ca.
# Retrieving data for city:bolpur,in.
# Retrieving data for city:podyuga,ru.
# Retrieving data for city:macamic,ca.
# Retrieving data for city:saquarema,br.
# Retrieving data for city:barroquinha,br.
# Retrieving data for city:hameenlinna,fi.
# Retrieving data for city:molina,cl.
# Retrieving data for city:nisia floresta,br.
# Retrieving data for city:mazagao,br.
# Retrieving data for city:padang,id.
# Retrieving data for city:inhambane,mz.
# Retrieving data for city:nioro,ml.
# No data found.
# Retrieving data for city:kirkland lake,ca.
# Retrieving data for city:salinas,ec.
# Retrieving data for city:rochegda,ru.
# Retrieving data for city:nsanje,mw.
# Retrieving data for city:lyuban,by.
# Retrieving data for city:derzhavinsk,kz.
# Retrieving data for city:feijo,br.
# Retrieving data for city:bonavista,ca.
# Retrieving data for city:kalmunai,lk.
# Retrieving data for city:karakendzha,tj.
# No data found.
# Retrieving data for city:placido de castro,br.
# Retrieving data for city:palafrugell,es.
# Retrieving data for city:raudeberg,no.
# Retrieving data for city:thunder bay,ca.
# Retrieving data for city:iberia,pe.
# Retrieving data for city:tempio pausania,it.
# Retrieving data for city:orlovka,ru.
# Retrieving data for city:mizan teferi,et.
# Retrieving data for city:chute-aux-outardes,ca.
# Retrieving data for city:diffa,ne.
# Retrieving data for city:pimentel,pe.
# Retrieving data for city:saint-joseph,re.
# Retrieving data for city:ikom,ng.
# Retrieving data for city:boddam,gb.
# Retrieving data for city:puerto ayora,ec.
# Retrieving data for city:jaciara,br.
# Retrieving data for city:solovetskiy,ru.
# No data found.
# Retrieving data for city:nuuk,gl.
# Retrieving data for city:itarema,br.
# Retrieving data for city:ponta delgada,pt.
# Retrieving data for city:hobyo,so.
# Retrieving data for city:brigantine,us.
# Retrieving data for city:carbonia,it.
# Retrieving data for city:raga,sd.
# No data found.
# Retrieving data for city:teguise,es.
# Retrieving data for city:nyrob,ru.
# Retrieving data for city:iskilip,tr.
# Retrieving data for city:dreznica,ba.
# Retrieving data for city:kholm,af.
# Retrieving data for city:muros,es.
# Retrieving data for city:caluquembe,ao.
# Retrieving data for city:umm jarr,sd.
# No data found.
# Retrieving data for city:primorsk,ru.
# Retrieving data for city:westport,ie.
# Retrieving data for city:coquimbo,cl.
# Retrieving data for city:totskoye,ru.
# Retrieving data for city:berlevag,no.
# Retrieving data for city:gramada,bg.
# Retrieving data for city:tortoli,it.
# Retrieving data for city:roxana,cr.
# Retrieving data for city:hinganghat,in.
# Retrieving data for city:arequipa,pe.
# Retrieving data for city:jiddah,sa.
# No data found.
# Retrieving data for city:quatre cocos,mu.
# Retrieving data for city:porto novo,cv.
# Retrieving data for city:vokhtoga,ru.
# Retrieving data for city:camabatela,ao.
# Retrieving data for city:karlstad,se.
# Retrieving data for city:portobelo,pa.
# Retrieving data for city:ponyri,ru.
# Retrieving data for city:viedma,ar.
# Retrieving data for city:kuva,uz.
# No data found.
# Retrieving data for city:yenagoa,ng.
# Retrieving data for city:kars,tr.
# Retrieving data for city:le port,re.
# Retrieving data for city:stavern,no.
# Retrieving data for city:atar,mr.
# Retrieving data for city:lebu,cl.
# Retrieving data for city:agadir,ma.
# Retrieving data for city:male,mv.
# Retrieving data for city:sumkino,ru.
# Retrieving data for city:cesky brod,cz.
# Retrieving data for city:ganganagar,in.
# Retrieving data for city:tarko-sale,ru.
# Retrieving data for city:gweta,bw.
# Retrieving data for city:mikhaylovka,kz.
# Retrieving data for city:vesyegonsk,ru.
# Retrieving data for city:puerto narino,co.
# Retrieving data for city:aiquile,bo.
# Retrieving data for city:mancio lima,br.
# No data found.
# Retrieving data for city:brae,gb.
# Retrieving data for city:grand gaube,mu.
# Retrieving data for city:kismayo,so.
# No data found.
# Retrieving data for city:cape canaveral,us.
# Retrieving data for city:umm kaddadah,sd.
# Retrieving data for city:usinsk,ru.
# Retrieving data for city:ringas,in.
# Retrieving data for city:sambava,mg.
# Retrieving data for city:salto del guaira,py.
# Retrieving data for city:lodja,cd.
# Retrieving data for city:muravlenko,ru.
# Retrieving data for city:mookane,bw.
# Retrieving data for city:bolungarvik,is.
# No data found.
# Retrieving data for city:igrim,ru.
# Retrieving data for city:antalaha,mg.
# Retrieving data for city:valdivia,cl.
# Retrieving data for city:po,bf.
# Retrieving data for city:skjervoy,no.
# Retrieving data for city:umzimvubu,za.
# No data found.
# Retrieving data for city:grand-santi,gf.
# Retrieving data for city:ostersund,se.
# Retrieving data for city:pilaia,gr.
# No data found.
# Retrieving data for city:aquiraz,br.
# Retrieving data for city:hit,iq.
# Retrieving data for city:svirstroy,ru.
# Retrieving data for city:muisne,ec.
# Retrieving data for city:rafaela,ar.
# Retrieving data for city:calama,cl.
# Retrieving data for city:camacha,pt.
# Retrieving data for city:sapele,ng.
# Retrieving data for city:gangotri,in.
# No data found.
# Retrieving data for city:conceicao da barra,br.
# Retrieving data for city:pisco,pe.
# Retrieving data for city:rodos,gr.
# Retrieving data for city:lubango,ao.
# Retrieving data for city:matay,eg.
# Retrieving data for city:nefteyugansk,ru.
# Retrieving data for city:skawina,pl.
# Retrieving data for city:constitucion,cl.
# Retrieving data for city:shache,cn.
# Retrieving data for city:klyuchi,ru.
# Retrieving data for city:bacalar,mx.
# Retrieving data for city:ilinskiy,ru.
# Retrieving data for city:pizarro,co.
# Retrieving data for city:boa vista,br.
# Retrieving data for city:am timan,td.
# Retrieving data for city:sao miguel do araguaia,br.
# Retrieving data for city:burica,pa.
# No data found.
# Retrieving data for city:moramanga,mg.
# Retrieving data for city:sinnamary,gf.
# Retrieving data for city:port-cartier,ca.
# Retrieving data for city:kangasala,fi.
# Retrieving data for city:luau,ao.
# Retrieving data for city:milevsko,cz.
# Retrieving data for city:malakal,sd.
# No data found.
# Retrieving data for city:kindu,cd.
# Retrieving data for city:safakulevo,ru.
# Retrieving data for city:sabanalarga,co.
# Retrieving data for city:uvira,cd.
# Retrieving data for city:huntington,us.
# Retrieving data for city:cairo,eg.
# Retrieving data for city:havre-saint-pierre,ca.
# Retrieving data for city:visby,se.
# Retrieving data for city:vigeland,no.
# Retrieving data for city:sao gabriel da cachoeira,br.
# Retrieving data for city:shahgarh,in.
# Retrieving data for city:ajdabiya,ly.
# Retrieving data for city:bambamarca,pe.
# Retrieving data for city:puerto ayacucho,ve.
# Retrieving data for city:badin,pk.
# Retrieving data for city:odweyne,so.
# No data found.
# Retrieving data for city:imamoglu,tr.
# Retrieving data for city:upington,za.
# Retrieving data for city:bull savanna,jm.
# Retrieving data for city:frolovo,ru.
# Retrieving data for city:vestbygda,no.
# No data found.
# Retrieving data for city:murighiol,ro.
# Retrieving data for city:nueve de julio,ar.
# Retrieving data for city:constantine,dz.
# Retrieving data for city:arlit,ne.
# Retrieving data for city:potosi,co.
# Retrieving data for city:anamur,tr.
# Retrieving data for city:tocopilla,cl.
# Retrieving data for city:rolim de moura,br.
# No data found.
# Retrieving data for city:tapiramuta,br.
# Retrieving data for city:seminole,us.
# Retrieving data for city:tessalit,ml.
# Retrieving data for city:tasbuget,kz.
# No data found.
# Retrieving data for city:los llanos de aridane,es.
# Retrieving data for city:vryburg,za.
# Retrieving data for city:caravelas,br.
# Retrieving data for city:bolobo,cd.
# Retrieving data for city:mehran,ir.
# Retrieving data for city:quelimane,mz.
# Retrieving data for city:resplendor,br.
# Retrieving data for city:talnakh,ru.
# Retrieving data for city:salacgriva,lv.
# Retrieving data for city:husavik,is.
# Retrieving data for city:herat,af.
# Retrieving data for city:honningsvag,no.
# Retrieving data for city:abu samrah,qa.
# No data found.
# Retrieving data for city:masuguru,tz.
# Retrieving data for city:itapaci,br.
# Retrieving data for city:kushmurun,kz.
# No data found.
# Retrieving data for city:kutum,sd.
# Retrieving data for city:onverwacht,sr.
# Retrieving data for city:alta floresta,br.
# Retrieving data for city:longlac,ca.
# No data found.
# Retrieving data for city:cascais,pt.
# Retrieving data for city:maragogi,br.
# Retrieving data for city:ejea de los caballeros,es.
# Retrieving data for city:turki,ru.
# Retrieving data for city:san borja,bo.
# Retrieving data for city:kudahuvadhoo,mv.
# Retrieving data for city:cabedelo,br.
# Retrieving data for city:yar-sale,ru.
# Retrieving data for city:radyvyliv,ua.
# Retrieving data for city:ylojarvi,fi.
# Retrieving data for city:nadym,ru.
# Retrieving data for city:knysna,za.
# Retrieving data for city:usagara,tz.
# Retrieving data for city:maykain,kz.
# No data found.
# Retrieving data for city:oskemen,kz.
# Retrieving data for city:cayenne,gf.
# Retrieving data for city:shibarghan,af.
# No data found.
# Retrieving data for city:sangueya,gn.
# Retrieving data for city:bol,td.
# Retrieving data for city:rio grande,br.
# Retrieving data for city:krasavino,ru.
# Retrieving data for city:sabang,id.
# Retrieving data for city:huarmey,pe.
# Retrieving data for city:maputo,mz.
# Retrieving data for city:vytegra,ru.
# Retrieving data for city:neuquen,ar.
# Retrieving data for city:vila velha,br.
# Retrieving data for city:mokhotlong,ls.
# Retrieving data for city:waddan,ly.
# Retrieving data for city:necochea,ar.
# Retrieving data for city:paralimni,cy.
# Retrieving data for city:el faiyum,eg.
# No data found.
# Retrieving data for city:puerto quijarro,bo.
# Retrieving data for city:aguimes,es.
# Retrieving data for city:kavaratti,in.
# Retrieving data for city:bafq,ir.
# Retrieving data for city:sochi,ru.
# Retrieving data for city:oranjemund,na.
# Retrieving data for city:alghero,it.
# Retrieving data for city:uvinza,tz.
# Retrieving data for city:gao,ml.
# Retrieving data for city:workington,gb.
# Retrieving data for city:talara,pe.
# Retrieving data for city:safaga,eg.
# No data found.
# Retrieving data for city:valparaiso,cl.
# Retrieving data for city:ludvika,se.
# Retrieving data for city:ciudad bolivar,ve.
# Retrieving data for city:sikasso,ml.
# Retrieving data for city:timmins,ca.
# Retrieving data for city:quedlinburg,de.
# Retrieving data for city:korablino,ru.
# Retrieving data for city:bindi,sl.
# Retrieving data for city:rocha,uy.
# Retrieving data for city:mwinilunga,zm.
# Retrieving data for city:khash,ir.
# Retrieving data for city:bar harbor,us.
# Retrieving data for city:nieuwpoort,an.
# No data found.
# Retrieving data for city:natal,br.
# Retrieving data for city:belpasso,it.
# Retrieving data for city:kalinovo,ru.
# Retrieving data for city:uramita,co.
# Retrieving data for city:sao fidelis,br.
# Retrieving data for city:murud,in.
# No data found.
# Retrieving data for city:de aar,za.
# Retrieving data for city:ajaccio,fr.
# Retrieving data for city:dunmore town,bs.
# Retrieving data for city:manitouwadge,ca.
# Retrieving data for city:goma,cd.
# Retrieving data for city:gasa,bt.
# Retrieving data for city:tawkar,sd.
# No data found.
# Retrieving data for city:muli,mv.
# Retrieving data for city:melfi,td.
# Retrieving data for city:kyzyl-suu,kg.
# Retrieving data for city:saintes,fr.
# Retrieving data for city:dzaoudzi,yt.
# Retrieving data for city:herrin,us.

# %%
# Convert list of tuples to df
new_meta = pd.DataFrame(list(meta_weather_summary))
new_meta.head()

# Change column labels
new_meta = new_meta.rename(columns={0:"City", 1:"Country Code", 2:"Longitude", 3:"Latitude", 4:"Temperature", 5:"Wind Speed", 6:"Cloudiness", 7: "Humidity"})
new_meta
# Out:
#                   City Country Code  Longitude  Latitude  Temperature  \
# 0              Ushuaia           AR     -68.31    -54.81        48.97
# 1             Hamilton           BM     -64.78     32.30        62.60
# 2       Saint-Philippe           RE      55.77    -21.36        73.40
# 3            Cape Town           ZA      18.42    -33.93        64.40
# 4       Puerto Cabezas           NI     -83.39     14.04        86.00
# 5            Gilleleje           DK      12.31     56.12        30.67
# 6      Arraial do Cabo           BR     -42.02    -22.97        86.00
# 7              Malanje           AO      16.35     -9.54        70.04
# 8       Vestmannaeyjar           IS     -20.27     63.44        40.88
# 9         Longyearbyen           SJ      15.64     78.22        10.40
# 10             Qaanaaq           GL     -69.36     77.48        -8.00
# 11          Bredasdorp           ZA      20.04    -34.53        68.00
# 12               Kochi           IN      76.25      9.96        84.20
# 13            Hermanus           ZA      19.24    -34.42        65.76
# 14            San Luis           AR     -66.34    -33.30        80.39
# 15          Baijiantan           CN      85.18     45.63        48.62
# 16             Salalah           OM      54.10     17.01        82.40
# 17             Ushtobe           KZ      77.98     45.25        39.53
# 18     Bambous Virieux           MU      57.76    -20.34        78.80
# 19                Suez           EG      32.54     29.97        64.10
# 20            Buraydah           SA      43.97     26.33        80.60
# 21             Iqaluit           CA     -68.52     63.75         1.40
# 22      Port Elizabeth           ZA      25.57    -33.92        69.80
# 23               Ravar           IR      56.81     31.27        52.85
# 24           Upernavik           GL     -56.15     72.79        -5.12
# 25         Port Alfred           ZA      26.89    -33.59        75.98
# 26                Lima           PE     -77.04    -12.06        73.77
# 27                 Sur           OM      59.53     22.57        77.51
# 28           Ilulissat           GL     -51.10     69.22        -0.41
# 29   Benjamin Constant           BR     -70.03     -4.38        79.72
# ..                 ...          ...        ...       ...          ...
# 493             Talara           PE     -81.27     -4.58        78.80
# 494         Valparaiso           CL     -71.63    -33.04        64.94
# 495            Ludvika           SE      15.18     60.15        23.00
# 496     Ciudad Bolivar           VE     -63.55      8.12        94.47
# 497            Sikasso           ML      -5.68     11.32        93.26
# 498            Timmins           CA     -81.33     48.48        33.80
# 499        Quedlinburg           DE      11.15     51.79        40.16
# 500          Korablino           RU      40.02     53.92        29.94
# 501              Bindi           SL     -11.45      9.91        96.23
# 502              Rocha           UY     -54.34    -34.48        71.93
# 503         Mwinilunga           ZM      24.43    -11.73        70.44
# 504              Khash           IR      61.21     28.22        53.30
# 505         Bar Harbor           US     -68.20     44.39        44.60
# 506              Natal           BR     -35.21     -5.81        86.00
# 507           Belpasso           IT      14.98     37.59        50.90
# 508           Kalinovo           RU      60.15     57.14        24.80
# 509            Uramita           CO     -76.17      6.90        72.06
# 510        Sao Fidelis           BR     -41.75    -21.65        86.00
# 511             De Aar           ZA      24.01    -30.65        66.26
# 512            Ajaccio           FR       8.74     41.93        54.10
# 513       Dunmore Town           BS     -76.65     25.50        70.49
# 514       Manitouwadge           CA     -85.84     49.12        32.00
# 515               Goma           CD      29.23     -1.67        60.41
# 516               Gasa           BT      89.73     27.91       -11.46
# 517               Muli           MV      73.57      2.92        84.08
# 518              Melfi           TD      17.94     11.06        89.97
# 519          Kyzyl-Suu           KG      78.00     42.34        34.17
# 520            Saintes           FR      -0.63     45.74        52.36
# 521           Dzaoudzi           YT      45.27    -12.79        78.80
# 522             Herrin           US     -89.03     37.80        55.85
#
#      Wind Speed  Cloudiness  Humidity
# 0         12.75          75        76
# 1         20.80          75        48
# 2          4.70           0        73
# 3          8.05           0        82
# 4          6.93          75        74
# 5         16.11          90        86
# 6         20.80          20        62
# 7          3.71           8        91
# 8         29.77          80        91
# 9          8.05          75        78
# 10         7.96           0        77
# 11        13.87          24        42
# 12         2.71          40        79
# 13         5.61          24        48
# 14        11.99           0        29
# 15         3.27          68        81
# 16         3.36           0        54
# 17         1.92          32        80
# 18         3.36          40        78
# 19         3.15          76        44
# 20         6.93           0        19
# 21         6.93          20        64
# 22         4.70           0        83
# 23         1.70           0        23
# 24        10.76           8        96
# 25        14.45          12        77
# 26         2.93           0        63
# 27         1.59           0        85
# 28         1.12          20        49
# 29         2.24          90        78
# ..          ...         ...       ...
# 493       11.41           0        69
# 494       10.29           0        72
# 495        3.36           0        57
# 496       12.21          44        41
# 497        7.96           8        22
# 498       10.29          90        97
# 499        4.61          76        85
# 500       10.09          88        97
# 501        6.62           0        19
# 502        9.75          56        67
# 503        3.71           0        77
# 504        3.15           0        20
# 505       10.29           1        22
# 506       18.34          40        66
# 507        8.05          40        62
# 508        4.47          40        92
# 509        1.92          80        87
# 510       12.75          20        55
# 511        6.73           0        26
# 512        3.36          90        76
# 513       21.50           0       100
# 514        4.70          90        93
# 515        1.14          12       100
# 516        1.92           0        31
# 517        2.26          92       100
# 518        2.71           0        40
# 519        2.15          92       100
# 520       11.41          90        93
# 521        4.70           0        88
# 522       11.41          90        93
#
# [523 rows x 8 columns]

# %%
# Save a CSV of all data retrieved
new_meta.to_csv("weather_metadata.csv", encoding='utf-8', index=True)

# %%
# Build a scatter plot that shows Temperature (F) vs. Latitude
plt.scatter(new_meta["Latitude"],
            new_meta["Temperature"],
            linewidths=1, marker="o",
            alpha=0.4, label="?")

# Label the graph and set axis limits
plt.title("Temperature vs. Latitude 3/27/2018")
plt.ylabel("Temperature(F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])

# Save the figure as png image (for each scatter plot) 
plt.savefig("temp_vs_latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot that shows Temperature (F) vs. Latitude
plt.scatter(new_meta["Latitude"],
            new_meta["Cloudiness"],
            linewidths=1, marker="o",
            alpha=0.4, label="?")

# Label the graph and set axis limits
plt.title("Cloudiness vs. Latitude 3/27/2018")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])

# Save the figure as png image 
plt.savefig("cloudiness_vs_latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot that shows Humidity (%) vs. Latitude
plt.scatter(new_meta["Latitude"],
            new_meta["Humidity"],
            linewidths=1, marker="o",
            alpha=0.4, label="?")

# Label the graph and set axis limits
plt.title("Humidity vs. Latitude 3/27/2018")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])

# Save the figure as png image 
plt.savefig("humidity_vs_latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot that shows Wind Speed (F) vs. Latitude
plt.scatter(new_meta["Latitude"],
            new_meta["Wind Speed"],
            linewidths=1, marker="o",
            alpha=0.4, label="?")

# Label the graph and set axis limits
plt.title("Wind Speed vs. Latitude 3/27/2018")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90,90])

# Save the figure as png image 
plt.savefig("windspeed_vs_latitude.png")

# Show plot
plt.show()
